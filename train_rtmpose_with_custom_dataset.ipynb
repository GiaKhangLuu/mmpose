# %%
# !ln -s /home/giakhang/dev/pose_sandbox/Hand_pose_estimation_3D/arm_and_hand/data .

# %%
# !python3 tools/misc/browse_dataset.py rtmpose-m_custom_dataset.py \
    --output-dir view_imgs \
    --max-item-per-dataset 100 \
    --phase val \
    --mode original \
    --not-show
# Out:
# loading annotations into memory...
# Done (t=0.28s)
# creating index...
# index created!
# /home/giakhang/py_venv/mmpose/lib/python3.10/site-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 100/100, 36.0 task/s, elapsed: 3s, ETA:     0s

# %%
# !python3 tools/train.py rtmpose-m_custom_dataset.py \
    --work-dir work_dirs \
    --show-dir work_dirs/rs_visualization
# Out:
# /home/giakhang/py_venv/mmpose/lib/python3.10/site-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# 08/17 16:06:06 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.14 (main, Apr  6 2024, 18:45:05) [GCC 9.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 21
#     GPU 0: NVIDIA GeForce GTX 1650 with Max-Q Design
#     CUDA_HOME: /usr/local/cuda-12.5
#     NVCC: Cuda compilation tools, release 12.5, V12.5.40
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 2.4.0+cu124
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
# ...

# %%
# Out:
# Unified val.json saved to data/unified_val.json

# %%
# Out:
# /home/giakhang/dev/pose_sandbox/mmpose
